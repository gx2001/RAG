# %% [markdown]
# Eystathios Andreopoulos 4630
# Giorgos Hatziligos 4835

# %% [markdown]
# #### -----------  Step 1 ----------- ####
#
# i.all initial imports
# ii.load data from CNN_Article_clean.csv and a sample
#
# #### -----------  Step 1 ----------- ####

# %%
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_ollama import OllamaLLM
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from sklearn.metrics.pairwise import cosine_similarity

df = pd.read_csv('CNN_Articels_clean.csv')


print("Data format:")
print(f"Number of articles: {len(df)}")
print(df.head())
# Out:
# Data format:
# Number of articles: 4076
#    Index                                             Author  \
# 0      0                                 Jacopo Prisco, CNN
# 1      2                              Stephanie Bailey, CNN
# 2      3  Words by Stephanie Bailey, video by Zahra Jamshed
# 3      4                    Paul R. La Monica, CNN Business
# 4      7                                            Reuters
#
#         Date published  Category    Section  \
# 0  2021-07-15 02:46:59      news      world
# 1  2021-05-12 07:52:09      news      world
# 2  2021-06-16 02:51:30      news       asia
# 3  2022-03-15 09:57:36  business  investing
# 4  2022-03-15 11:27:02  business   business
#
#                                                  Url  \
# 0  https://www.cnn.com/2021/07/14/world/tusimple-...
# 1  https://www.cnn.com/2021/05/12/world/ironhand-...
# 2  https://www.cnn.com/2021/06/15/asia/swarm-robo...
# 3  https://www.cnn.com/2022/03/15/investing/brics...
# 4  https://www.cnn.com/2022/03/15/business/russia...
#
#                                             Headline  \
# 0  There's a shortage of truckers, but TuSimple t...
# 1  Bioservo's robotic 'Ironhand' could protect fa...
# 2  This swarm of robots gets smarter the more it ...
# 3  Russia is no longer an option for investors. T...
# 4  Russian energy investment ban part of new EU s...
#
#                                          Description  \
# 0  The e-commerce boom has exacerbated a global t...
# 1  Working in a factory can mean doing the same t...
# 2  In a Hong Kong warehouse, a swarm of autonomou...
# 3  For many years, the world's most popular emerg...
# 4  The European Union formally approved on Tuesda...
#
#                                             Keywords  \
# 0  world, There's a shortage of truckers, but TuS...
# 1  world, Bioservo's robotic 'Ironhand' could pro...
# 2  asia, This swarm of robots gets smarter the mo...
# 3  investing, Russia is no longer an option for i...
# 4  business, Russian energy investment ban part o...
#
#                                      Second headline  \
# 0  There's a shortage of truckers, but TuSimple t...
# 1  A robotic 'Ironhand' could protect factory wor...
# 2  This swarm of robots gets smarter the more it ...
# 3  Russia is no longer an option for investors. T...
# 4  EU bans investment in Russian energy in new sa...
#
#                                         Article text
# 0   (CNN)Right now, there's a shortage of truck d...
# 1   (CNN)Working in a factory or warehouse can me...
# 2   (CNN)In a Hong Kong warehouse, a swarm of aut...
# 3  New York (CNN Business)For many years, the wor...
# 4  The European Union formally approved on Tuesda...

# %% [markdown]
# -------------------------------------------------------------- Step 2 -----------------------------------------------------------
#
# Preprocessing Step : This step splits into smaller chunks
#
# 2.1.RecursiveCharacterTextSplitter divides text based on natural separarators
#
# 2.2.We hold from the CNN_Articles_clean column : "Headline" and "Article text" and we combine them
#
# 2.3.Split the text from the combnation of them  "Headline" and "Article text" as a chunk and put it in a list of chunks
#
# 2.4.Metadata for each chunk like idx , chunk_id , title/headline **we can add more**
#
# -------------------------------------------------------------- Step 2 ----------------------------------------------------------

# %%
# Create the text splitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,         # Size of each chunk (in characters)
    chunk_overlap=80,       # Overlap between chunks (for better continuity)
    length_function=len,     # Function for measuring size (here simply counting characters)
    separators=["\n\n", "\n", ".", " ", ""]  # Preferred splitting points
)


all_chunks = []
all_metadatas = []


for idx, row in tqdm(df.iterrows(), total=len(df), desc="Splitting articles into chunks"):
    title = row['Headline'] if not pd.isna(row['Headline']) else ""
    content = row['Article text'] if not pd.isna(row['Article text']) else ""
    
    # Combine title and content with a separator
    full_text = f"Title: {title}\n\nContent: {content}"
    #full_text = f"Content: {content}"
    # Split the text into chunks
    chunks = text_splitter.split_text(full_text)
    
    # Add the chunks to the lists
    all_chunks.extend(chunks)
    
    # Add metadata for each chunk
    for i in range(len(chunks)):
        metadata = {
            'title': title,
            'article_id': idx,
            'chunk_id': i,
            'source': 'CNN'
        }
        all_metadatas.append(metadata)

print(f"Total number of chunks: {len(all_chunks)}")
print(f"Example chunk: {all_chunks[0][:200]}...")
# Out:
# Splitting articles into chunks: 100%|██████████| 4076/4076 [00:00<00:00, 5615.57it/s]
# Total number of chunks: 59420
# Example chunk: Title: There's a shortage of truckers, but TuSimple thinks it has a solution: no driver needed - CNN...

# %% [markdown]
# -------------------------------------------------------------- Step 3 -----------------------------------------------------------
#
# Initialize a emdedding model
#
# examples of models
#
# sentence-transformers/all-MiniLM-L6-v2
#
# sentence-transformers/all-mpnet-base-v2 # Higher quality embeddings, but larger and slower , More powerful model
#
# sentence-transformers/all-MiniLM-L12-v2 # Deeper model
#
# -------------------------------------------------------------- Step 3 -----------------------------------------------------------

# %%
embeddings_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2",
    model_kwargs={'device': 'cpu'},  
    encode_kwargs={'normalize_embeddings': True}  
)

# %% [markdown]
# -------------------------------------------------------------- Step 3_1 -----------------------------------------------------------
#
# Create the vector database
#
# This step converts all text chunks into vector embeddings and stores them in a FAISS index
#
# FAISS enables efficient similarity search across large collections of embeddings
#
# Create the vector database from texts and their embedding
#
# -------------------------------------------------------------- Step 3_1 -----------------------------------------------------------

# %%
# Create the vector database
vectorstore = FAISS.from_texts(
    texts=all_chunks,
    embedding=embeddings_model,
    metadatas=all_metadatas
)

# Save the database to disk
vectorstore.save_local("faiss_index")

print("The vector database was created and saved successfully!")
# Out:
# The vector database was created and saved successfully!

# %% [markdown]
# -------------------------------------------------------------- Step 4 -----------------------------------------------------------
#
#
# 4.1 : This step sets up the Large Language Model : llama3.2:1b , llama3.2:3b & temprature = 0.1
#
# 4.2 : we can set the temperature as 0 to take the same response of llm always with a specific question
#
# -------------------------------------------------------------- Step 4 -----------------------------------------------------------

# %%
try:
    # Initialize the Llama model via Ollama
    llm = OllamaLLM(model="llama3.2:3b", temperature=0.1)
    
    # Check that the LLM is working correctly
    test_response = llm.invoke("which is the current president of Greece")
    print(f"Test response from LLM: {test_response}")
except Exception as e:
    print(f"Error initializing LLM: {e}")
    print("Make sure that:")
    print("1. You have installed ollama from https://ollama.com/download")
    print("2. You have run: ollama pull llama3.2:1b or llama3.2:3b")
    print("3. Ollama is running in the background: ollama serve")
# Out:
# Test response from LLM: I don't have real-time information, but as of my knowledge cutoff in December 2023, the President of Greece was Katerina Sakellaropoulou. However, please note that this information may have changed since then.
#
# For the most up-to-date information, I recommend checking a reliable news source or the official website of the Greek Presidency for the latest information on the current president of Greece.

# %% [markdown]
# -------------------------------------------------------------- Step 5 -----------------------------------------------------------
#
# This step sets up the prompt template and the retrieval-based QA chain
#
# The chain will retrieve relevant chunks and feed them to the LLM to generate answers
#
# -------------------------------------------------------------- Step 5 -----------------------------------------------------------

# %%
# Create the template for the prompt
template = """
You are an AI assistant. Answer the following question.
Answer the following question: {question}

Base your answer on the following context:
{context}

Instructions:
- Use the information from the context above to answer the question
- If the context contains relevant information, provide a detailed answer

Answer:
"""

# Create the PromptTemplate
PROMPT = PromptTemplate(
    template=template,
    input_variables=["question", "context"]
)

# Create the question-answer chain with retrieval (RetrievalQA)
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",  # Simple strategy that "stuffs" all retrieved texts into the prompt
    retriever=vectorstore.as_retriever(search_kwargs={"k": 10}),  # Retrieve the top-20 relevant chunks
    chain_type_kwargs={"prompt": PROMPT},
    return_source_documents=True  # Returns also the documents used
)

# %% [markdown]
# -------------------------------------------------------------- Step 5 -----------------------------------------------------------
#
# Define Query functions
#
# 1.)  Process a question using the RAG .
#
# 1.1) We use the the question-answer chain to answer the question and keep from the answer the retrieved docs from dataset which is used
#
# 1.2)we print the question , answer of llm , chunk index , and the idx , headline , Article text
#
# 2.)  Process a question using the the llm .
#
# 2.1) We simply make a prompt with an faculty + question
#
# 2.2) We gave it in the llm and it answers it .
#
#
#
# -------------------------------------------------------------- Step 5 -----------------------------------------------------------

# %%
def get_retrieval_similarity_scores(question, retrieved_docs, embeddings_model):
    
    
    question_embedding = embeddings_model.embed_query(question)
    
    print("\nSimilarity scores between question and retrieved chunks:")
    print("-" * 80)
    
    similarity_results = []
    
    for i, doc in enumerate(retrieved_docs):
        # Get document embedding only with previous model 
        doc_embedding = embeddings_model.embed_query(doc.page_content)
        
        # Calculate cosine similarity 
        similarity = cosine_similarity([question_embedding], [doc_embedding])[0][0]
        
        title = doc.metadata.get('title', '')
        
        # Store result
        similarity_results.append({
            'index': i+1,
            'article_id': doc.metadata.get('article_id'),
            'chunk_id': doc.metadata.get('chunk_id'),
            'similarity': similarity,
            'title': title
        })
        
        # Print result with proper title display
        print(f"Chunk {i+1} (Article {doc.metadata.get('article_id')}, Chunk {doc.metadata.get('chunk_id')})")
        print(f"Title: {title}")  
        print(f"Similarity Score: {similarity:.4f}")
        print("-" * 80)
    
    # Print statistics
    avg_similarity = np.mean([r['similarity'] for r in similarity_results])
    max_similarity = max([r['similarity'] for r in similarity_results])
    min_similarity = min([r['similarity'] for r in similarity_results])
    
    print(f"\nSimilarity Statistics:")
    print(f"Average similarity score: {avg_similarity:.4f}")
    print(f"Maximum similarity score: {max_similarity:.4f}")
    print(f"Minimum similarity score: {min_similarity:.4f}")
    
    return similarity_results

# %%
def query_with_rag(question):
    result = qa_chain.invoke({"query": question})
    answer = result["result"]
    source_docs = result["source_documents"]
    
    print(f"Question: {question}")
    print(f"Answer (with RAG): {answer}")
    
    
    similarity_scores = get_retrieval_similarity_scores(question, source_docs, embeddings_model)
    
    print("\nThe following chunks were used:")
    for i, doc in enumerate(source_docs):
        print(f"\nChunk {i+1}:")
        print(f"Metadata: {doc.metadata}")
        print(f"Content: {doc.page_content[:200]}...")  
    
    return answer, source_docs, similarity_scores

# Function for answering questions directly with the LLM 
def query_without_rag(question):
    prompt = f"You are an artificial intelligence assistant who is an expert in analyzing from CNN articles 2020 - 2022. Answer the following question:: {question}"
    answer = llm.invoke(prompt)
    
    print(f"Question: {question}")
    print(f"Answer (without RAG): {answer}")
    
    return answer

# %% [markdown]
# -------------------------------------------------------------- Step 6 -----------------------------------------------------------
#
# Evaluate Question - Answer
#
# 1.) 5 question
#
# 2.) for each question print
#
# 2.1) with rag -> the index of question , question , retrieved docs with the headline , Article text , idx , chunk_id , answer
#
# 2.2.) without  ->  the index of question , question , answer
#
# 3.) Save all in a csv
#
# -------------------------------------------------------------- Step 6 -----------------------------------------------------------

# %%
question_array = [
    
    "How did the COVID-19 pandemic affect the global economy?",
    "News about the summer Olymbic games 2020 ?",
    "What are John Biden's plans for the American economy ?",
    "What are the player transfers for football teams?",
    "What are the main challenges currently facing U.S.Α domestic and foreign policy ?"

]


print("######################################## RAG SYSTEM EVALUATION ########################################")
print("=======================================================================================================")
results = []

for q_idx, question in enumerate(question_array):
    print(f"\n\nQUESTION {q_idx+1}: {question}")
    print("#" * 80)
    
    # Answer with RAG
    print("\n[WITH RAG]")
    try:
        with_rag_answer, source_docs, similarity_scores = query_with_rag(question)
    except Exception as e:
        print(f"Error during RAG execution: {e}")
        with_rag_answer = "Error in RAG execution"
        source_docs = []
        similarity_scores = []
    
    # Answer without RAG
    print("\n[WITHOUT RAG]")
    try:
        without_rag_answer = query_without_rag(question)
    except Exception as e:
        print(f"Error during execution without RAG: {e}")
        without_rag_answer = "Error in execution without RAG"
    
    # Save results
    results.append({
        "question": question,
        "with_rag": with_rag_answer,
        "without_rag": without_rag_answer,
        "source_docs": source_docs,
        "similarity_scores": similarity_scores
    })
    
    print("\n" + "#" * 80)


evaluation_df = pd.DataFrame([
    {
        "question": r["question"],
        "with_rag_answer": r["with_rag"],
        "without_rag_answer": r["without_rag"],
        "num_source_docs": len(r["source_docs"]),
        "avg_similarity": np.mean([s["similarity"] for s in r["similarity_scores"]]) if r["similarity_scores"] else 0,
        "max_similarity": max([s["similarity"] for s in r["similarity_scores"]]) if r["similarity_scores"] else 0,
        "min_similarity": min([s["similarity"] for s in r["similarity_scores"]]) if r["similarity_scores"] else 0
    }
    for r in results
])


print("\nSummary evaluation results:")
print(evaluation_df[["question", "num_source_docs", "avg_similarity", "max_similarity", "min_similarity"]])


evaluation_df.to_csv("rag_evaluation_results_with_similarity.csv", index=False)
print("=======================================================================================================")
print("#################################### END RAG SYSTEM EVALUATION ########################################")
# Out:
# ######################################## RAG SYSTEM EVALUATION ########################################
# =======================================================================================================
#
#
# QUESTION 1: How did the COVID-19 pandemic affect the global economy?
# ################################################################################
#
# [WITH RAG]
# Question: How did the COVID-19 pandemic affect the global economy?
# Answer (with RAG): The COVID-19 pandemic had a significant impact on the global economy, with far-reaching consequences that are still being felt today. One of the most notable effects was the massive job loss in the labor market, with 22 million jobs lost in just two months in the US, which is more than twice as many jobs lost during the entire Great Recession and financial crisis of 2008-2009.
#
# The pandemic also led to a global supply chain disruption, resulting in inflation. However, it's worth noting that this inflation was largely due to global supply chain problems, rather than the strong jobs recovery that has since occurred. Without this strong recovery, the burst of mostly inevitable inflation would have been much more damaging to working families.
#
# Furthermore, the pandemic highlighted the need for a better and fairer economy, with many obstacles yet to be addressed. The lack of action to address environmental risks, such as incentivizing farmers and rural workers to adopt productive and regenerative agriculture, has not translated into meaningful change.
#
# The ongoing COVID-19 pandemic in China is another threat to the economy, with new lockdowns and restrictions potentially affecting exports and imports of electronic parts and goods, leading to further inflation. The government acknowledges that new COVID outbreaks could weigh on the economy in the coming months, highlighting the need for continued vigilance and action to mitigate the economic impact of future pandemics.
#
# In summary, the COVID-19 pandemic has had a profound impact on the global economy, with significant job losses, supply chain disruptions, and inflation. However, it has also highlighted the need for a more sustainable and equitable approach to economic development, one that prioritizes environmental protection and social welfare.
#
# Similarity scores between question and retrieved chunks:
# --------------------------------------------------------------------------------
# Chunk 1 (Article 251, Chunk 1)
# Title: Opinion: The economy is recovering fast. But we need to ensure it works for everyone - CNN
# Similarity Score: 0.6404
# --------------------------------------------------------------------------------
# Chunk 2 (Article 250, Chunk 5)
# Title: Opinion: Why protecting the planet is essential to preventing future pandemics - CNN
# Similarity Score: 0.6364
# --------------------------------------------------------------------------------
# Chunk 3 (Article 251, Chunk 11)
# Title: Opinion: The economy is recovering fast. But we need to ensure it works for everyone - CNN
# Similarity Score: 0.6290
# --------------------------------------------------------------------------------
# Chunk 4 (Article 19, Chunk 7)
# Title: Economic growth in 2022: China had a surprisingly good start, but it may not last - CNN
# Similarity Score: 0.5991
# --------------------------------------------------------------------------------
# Chunk 5 (Article 391, Chunk 17)
# Title: League of Legends is growing. Traditional sports better watch out.  - CNN
# Similarity Score: 0.5900
# --------------------------------------------------------------------------------
# Chunk 6 (Article 250, Chunk 1)
# Title: Opinion: Why protecting the planet is essential to preventing future pandemics - CNN
# Similarity Score: 0.5868
# --------------------------------------------------------------------------------
# Chunk 7 (Article 211, Chunk 6)
# Title: Premarket stocks: China's new Covid lockdowns are another threat to the economy - CNN
# Similarity Score: 0.5848
# --------------------------------------------------------------------------------
# Chunk 8 (Article 19, Chunk 8)
# Title: Economic growth in 2022: China had a surprisingly good start, but it may not last - CNN
# Similarity Score: 0.5811
# --------------------------------------------------------------------------------
# Chunk 9 (Article 45, Chunk 34)
# Title: Dr. Sanjay Gupta: Is America ready to take the next step in its Covid-19 recovery? - CNN
# Similarity Score: 0.5766
# --------------------------------------------------------------------------------
# Chunk 10 (Article 3321, Chunk 11)
# Title: UK Covid: British government's early response to virus slammed in new report - CNN
# Similarity Score: 0.5671
# --------------------------------------------------------------------------------
#
# Similarity Statistics:
# Average similarity score: 0.5991
# Maximum similarity score: 0.6404
# Minimum similarity score: 0.5671
#
# The following chunks were used:
#
# Chunk 1:
# Metadata: {'title': 'Opinion: The economy is recovering fast. But we need to ensure it works for everyone - CNN', 'article_id': 251, 'chunk_id': 1, 'source': 'CNN'}
# Content: When the coronavirus pandemic shut down businesses across the US in spring 2020, the labor market lost 22 million jobs in just two months — more than twice as many jobs lost during the entire Great Re...
#
# Chunk 2:
# Metadata: {'title': 'Opinion: Why protecting the planet is essential to preventing future pandemics - CNN', 'article_id': 250, 'chunk_id': 5, 'source': 'CNN'}
# Content: .Unfortunately, the awareness of these nature-related risks has not translated into action that would help head off future pandemics. Too many Covid-19 recovery plans have so far demonstrably failed t...
#
# Chunk 3:
# Metadata: {'title': 'Opinion: The economy is recovering fast. But we need to ensure it works for everyone - CNN', 'article_id': 251, 'chunk_id': 11, 'source': 'CNN'}
# Content: . But this inflation was largely from global supply chain problems, and without the strong jobs recovery we have today, this burst of mostly inevitable inflation would've been much more damaging to wo...
#
# Chunk 4:
# Metadata: {'title': 'Economic growth in 2022: China had a surprisingly good start, but it may not last - CNN', 'article_id': 19, 'chunk_id': 7, 'source': 'CNN'}
# Content: .China's new Covid lockdowns are another threat to the economyThe worst Covid-19 surge in two yearsChina is fighting its worst Covid surge since the original outbreak in Wuhan in early 2020...
#
# Chunk 5:
# Metadata: {'title': 'League of Legends is growing. Traditional sports better watch out.  - CNN', 'article_id': 391, 'chunk_id': 17, 'source': 'CNN'}
# Content: . There was also a downside. A lot of the companies, especially big companies, are struggling with coronavirus. "Media spending, marketing spending just decreased and this also hits the esports market...
#
# Chunk 6:
# Metadata: {'title': 'Opinion: Why protecting the planet is essential to preventing future pandemics - CNN', 'article_id': 250, 'chunk_id': 1, 'source': 'CNN'}
# Content: Almost two years since the start of the Covid-19 pandemic, scientific breakthroughs powered by international collaboration have helped us create vaccines and other treatments that can help tackle the ...
#
# Chunk 7:
# Metadata: {'title': "Premarket stocks: China's new Covid lockdowns are another threat to the economy - CNN", 'article_id': 211, 'chunk_id': 6, 'source': 'CNN'}
# Content: . "That will then affect exports and imports of electronic parts and goods."That could make inflation even worse. Spending inside China, an important engine of the country's growth, could also be affe...
#
# Chunk 8:
# Metadata: {'title': 'Economic growth in 2022: China had a surprisingly good start, but it may not last - CNN', 'article_id': 19, 'chunk_id': 8, 'source': 'CNN'}
# Content: ."With officials ditching targeted containment measures in favor of wholesale lockdowns, this has the potential to be even more disruptive than the Delta wave last Summer, which led to a sharp contrac...
#
# Chunk 9:
# Metadata: {'title': 'Dr. Sanjay Gupta: Is America ready to take the next step in its Covid-19 recovery? - CNN', 'article_id': 45, 'chunk_id': 34, 'source': 'CNN'}
# Content: . Global Covid-19 deaths surpass 6 millionInarguably, the course of humanity has been shaped by malaria: It's believed to have contributed to the fall of Rome, and for hundreds of years, it helped pro...
#
# Chunk 10:
# Metadata: {'title': "UK Covid: British government's early response to virus slammed in new report - CNN", 'article_id': 3321, 'chunk_id': 11, 'source': 'CNN'}
# Content: . "What was being achieved in other countries, particularly East Asia, appeared to be of little interest in the initial weeks of the pandemic," the report added. "This was an inexcusable oversight...
#
# [WITHOUT RAG]
# Question: How did the COVID-19 pandemic affect the global economy?
# Answer (without RAG): The COVID-19 pandemic had a profound impact on the global economy, with far-reaching consequences for businesses, industries, and individuals worldwide.
#
# According to a report by the International Monetary Fund (IMF), the pandemic led to a significant decline in global economic output, with the IMF estimating that the world economy contracted by 3.5% in 2020, compared to a growth rate of 3.2% in 2019. The pandemic also led to widespread job losses, with an estimated 114 million jobs lost globally in 2020 alone.
#
# The impact of the pandemic on the global economy was felt across various sectors, including:
#
# 1. Tourism and hospitality: The pandemic led to a sharp decline in international travel and tourism, resulting in significant losses for airlines, hotels, and other related businesses.
# 2. Retail and consumer goods: Non-essential retail stores were forced to close, leading to a decline in sales and revenue for many companies.
# 3. Manufacturing and supply chains: Disruptions to global supply chains, including lockdowns and border closures, led to shortages and delays in the delivery of essential goods.
# 4. Energy and commodities: The pandemic led to a significant decline in oil prices, which had a ripple effect on the energy sector and other commodity markets.
#
# However, the pandemic also accelerated the adoption of digital technologies and remote work arrangements, which may have long-term benefits for businesses and individuals.
#
# According to a report by McKinsey & Company, the pandemic led to a significant increase in remote work, with 51% of companies adopting flexible work arrangements. This shift towards remote work is expected to continue even after the pandemic subsides, potentially leading to increased productivity and reduced costs for businesses.
#
# In terms of specific countries, some of the hardest-hit economies included:
#
# 1. Italy: The country's economy contracted by 9.5% in 2020, with widespread lockdowns and travel restrictions having a significant impact on the tourism and hospitality sectors.
# 2. Spain: The country's economy contracted by 11.8% in 2020, with the tourism sector being particularly hard hit due to border closures and travel restrictions.
# 3. South Africa: The country's economy contracted by 7.4% in 2020, with widespread lockdowns and social distancing measures having a significant impact on businesses and industries.
#
# On the other hand, some countries were less affected by the pandemic, including:
#
# 1. China: The country's economy contracted by 2.3% in 2020, with the government implementing strict controls to mitigate the spread of the virus.
# 2. Singapore: The country's economy contracted by 4.5% in 2020, but the government's swift response and effective containment measures helped minimize the impact on businesses and industries.
#
# Overall, the COVID-19 pandemic had a profound impact on the global economy, with far-reaching consequences for businesses, industries, and individuals worldwide. While some countries were more affected than others, the pandemic accelerated the adoption of digital technologies and remote work arrangements, which may have long-term benefits for businesses and individuals.
#
# Sources:
#
# * International Monetary Fund (IMF). (2020). World Economic Outlook: Navigating a New Normal.
# * McKinsey & Company. (2020). The future of work in the COVID-19 era.
# * CNN. (2020). How the pandemic is affecting the global economy.
# * BBC News. (2020). Global economy: What's happening and what's next?
# * World Bank. (2020). COVID-19 and the world economy.
#
# Note: The information provided is based on articles from CNN, 2020-2022.
#
# ################################################################################
#
#
# QUESTION 2: News about the summer Olymbic games 2020 ?
# ################################################################################
#
# [WITH RAG]
# Question: News about the summer Olymbic games 2020 ?
# Answer (with RAG): Based on the provided context, here is the answer to the question about news related to the Summer Olympic Games 2020:
#
# The Summer Olympic Games 2020 were postponed due to the COVID-19 pandemic and are now scheduled to take place from July 23 to August 8, 2021. The games were initially set to begin in 2020 but were delayed by a year.
#
# As of the current time (six months before the scheduled start date), it is still unclear whether fans will be allowed to watch the Games due to the ongoing COVID-19 pandemic. Organizers have stated that a decision on the number of overall spectators permitted within stadiums and from outside of Japan will be made by spring.
#
# Additionally, two updated versions of the "Playbook" are expected to be published in April and June, which will provide further guidance on how the Games will take place.
#
# It's worth noting that the postponement of the Tokyo Olympics has raised concerns about the ability of countries to host large sporting events during a pandemic. The context mentions that events in Beijing are scheduled to begin on February 4, 2022, just over 12 months away, but it's unclear whether the Games will take place as planned.
#
# Overall, the situation surrounding the Summer Olympic Games 2020 is complex and uncertain, with many factors still being decided by organizers.
#
# Similarity scores between question and retrieved chunks:
# --------------------------------------------------------------------------------
# Chunk 1 (Article 835, Chunk 9)
# Title: Olympics 2021: Japan and IOC determined to hold Tokyo Games despite cancellation rumors - CNN
# Similarity Score: 0.6293
# --------------------------------------------------------------------------------
# Chunk 2 (Article 1174, Chunk 7)
# Title: Tokyo Olympics: IOC says athletes will not need vaccine to participate - CNN
# Similarity Score: 0.5873
# --------------------------------------------------------------------------------
# Chunk 3 (Article 787, Chunk 25)
# Title: Tokyo Olympics: Can vaccines save the Games?  - CNN
# Similarity Score: 0.5806
# --------------------------------------------------------------------------------
# Chunk 4 (Article 800, Chunk 23)
# Title: Beijing Olympics: The US has accused China of Xinjiang genocide. Will it now boycott the 2022 Games? - CNN
# Similarity Score: 0.5669
# --------------------------------------------------------------------------------
# Chunk 5 (Article 1998, Chunk 0)
# Title: 2020 Tokyo Olympics: Serena Williams confirms she will not play at summer Games - CNN
# Similarity Score: 0.5662
# --------------------------------------------------------------------------------
# Chunk 6 (Article 1106, Chunk 2)
# Title: Lindsey Vonn discuss challenges facing Olympians, her 'struggles' after retirement and athlete activism - CNN
# Similarity Score: 0.5632
# --------------------------------------------------------------------------------
# Chunk 7 (Article 1476, Chunk 2)
# Title: NFL Draft 2021 explainer: Everything you need to know  - CNN
# Similarity Score: 0.5593
# --------------------------------------------------------------------------------
# Chunk 8 (Article 2522, Chunk 0)
# Title: Euro 2020: Staging semis and final in London is 'recipe for disaster.' Is football -- and Covid-19 spike -- coming home? - CNN
# Similarity Score: 0.5575
# --------------------------------------------------------------------------------
# Chunk 9 (Article 793, Chunk 2)
# Title: Pulling off Tokyo Olympics in 2021 will be a logistical nightmare, and the clock is ticking - CNN
# Similarity Score: 0.5573
# --------------------------------------------------------------------------------
# Chunk 10 (Article 2343, Chunk 0)
# Title: Overshadowed by Covid-19, Olympic athletes are left to bring light to troubled Tokyo 2020 - CNN
# Similarity Score: 0.5571
# --------------------------------------------------------------------------------
#
# Similarity Statistics:
# Average similarity score: 0.5725
# Maximum similarity score: 0.6293
# Minimum similarity score: 0.5571
#
# The following chunks were used:
#
# Chunk 1:
# Metadata: {'title': 'Olympics 2021: Japan and IOC determined to hold Tokyo Games despite cancellation rumors - CNN', 'article_id': 835, 'chunk_id': 9, 'source': 'CNN'}
# Content: . "We continue in our preparation to participate at Tokyo 2020 with a focus on the health and safety of our athletes, their families, and their communities." Saturday marks six months until the postpo...
#
# Chunk 2:
# Metadata: {'title': 'Tokyo Olympics: IOC says athletes will not need vaccine to participate - CNN', 'article_id': 1174, 'chunk_id': 7, 'source': 'CNN'}
# Content: ." It is still unclear whether fans will be allowed to watch the Games, with confirmed Covid-19 cases still surging across the world. On Wednesday, organizers said a decision on the number of overall ...
#
# Chunk 3:
# Metadata: {'title': 'Tokyo Olympics: Can vaccines save the Games?  - CNN', 'article_id': 787, 'chunk_id': 25, 'source': 'CNN'}
# Content: ."We are not speculating on whether the games will take place, we are working on how the Games will take place," he said, adding that "more than 7,000 sports events have been organized by the internat...
#
# Chunk 4:
# Metadata: {'title': 'Beijing Olympics: The US has accused China of Xinjiang genocide. Will it now boycott the 2022 Games? - CNN', 'article_id': 800, 'chunk_id': 23, 'source': 'CNN'}
# Content: .And that's assuming the Games even go ahead as planned. Events in Beijing are scheduled to begin on Friday, February 4, 2022 -- just over 12 months away. But as the postponement of last year's Summer...
#
# Chunk 5:
# Metadata: {'title': '2020 Tokyo Olympics: Serena Williams confirms she will not play at summer Games - CNN', 'article_id': 1998, 'chunk_id': 0, 'source': 'CNN'}
# Content: Title: 2020 Tokyo Olympics: Serena Williams confirms she will not play at summer Games - CNN...
#
# Chunk 6:
# Metadata: {'title': "Lindsey Vonn discuss challenges facing Olympians, her 'struggles' after retirement and athlete activism - CNN", 'article_id': 1106, 'chunk_id': 2, 'source': 'CNN'}
# Content: .But even someone as resilient as Vonn doesn't get how athletes are coping in the ever-changing landscape of a global pandemic after the Tokyo Olympics' postponement in 2020, and -- despite fevered sp...
#
# Chunk 7:
# Metadata: {'title': 'NFL Draft 2021 explainer: Everything you need to know  - CNN', 'article_id': 1476, 'chunk_id': 2, 'source': 'CNN'}
# Content: .  Increasing in extravagance over the years -- 2020's edition was set for a floating stage in the Fountains of the Bellagio in Las Vegas -- the coronavirus pandemic forced a drastic scaling back of p...
#
# Chunk 8:
# Metadata: {'title': "Euro 2020: Staging semis and final in London is 'recipe for disaster.' Is football -- and Covid-19 spike -- coming home? - CNN", 'article_id': 2522, 'chunk_id': 0, 'source': 'CNN'}
# Content: Title: Euro 2020: Staging semis and final in London is 'recipe for disaster.' Is football -- and Covid-19 spike -- coming home? - CNN...
#
# Chunk 9:
# Metadata: {'title': 'Pulling off Tokyo Olympics in 2021 will be a logistical nightmare, and the clock is ticking - CNN', 'article_id': 793, 'chunk_id': 2, 'source': 'CNN'}
# Content: ."Tokyo 2020 might need a miracle. After the Covid-19 pandemic forced organizers to delay the Summer Olympics last year, the Games are now set to begin in less than six months on July 23, and major qu...
#
# Chunk 10:
# Metadata: {'title': 'Overshadowed by Covid-19, Olympic athletes are left to bring light to troubled Tokyo 2020 - CNN', 'article_id': 2343, 'chunk_id': 0, 'source': 'CNN'}
# Content: Title: Overshadowed by Covid-19, Olympic athletes are left to bring light to troubled Tokyo 2020 - CNN...
#
# [WITHOUT RAG]
# Question: News about the summer Olymbic games 2020 ?
# Answer (without RAG): The Summer Olympic Games were postponed to 2021 due to the COVID-19 pandemic, but I can provide you with some information on the original plans and eventual changes.
#
# According to CNN articles from 2020, the Summer Olympic Games were initially scheduled to take place in Tokyo, Japan from July 24 to August 9, 2020. However, on March 24, 2020, the International Olympic Committee (IOC) announced that the games would be postponed to 2021 due to the ongoing pandemic.
#
# In an interview with CNN's Christiane Amanpour, IOC President Thomas Bach explained that the decision was made after careful consideration and consultation with various stakeholders. He stated that the postponement would allow for a safer environment for athletes, officials, and spectators, as well as provide more time for preparations and planning.
#
# The 2020 Summer Olympics were eventually held from July 23 to August 8, 2021, in Tokyo, Japan. The games featured over 11,000 athletes from around the world competing in 33 sports and 50 disciplines.
#
# Some notable news stories from CNN about the 2020 Summer Olympics include:
#
# * "Tokyo 2020: A new era for the Olympics?" (March 24, 2020) - This article discussed the IOC's decision to postpone the games due to the pandemic.
# * "Olympic Games postponed to 2021" (July 23, 2020) - This article reported on the official announcement of the postponement and provided details on the new dates for the games.
# * "Tokyo Olympics: A COVID-19 'bubble' is being created for athletes" (August 2, 2021) - This article explained the measures being taken to create a safe environment for athletes during the games.
#
# I hope this information helps! Let me know if you have any further questions.
#
# ################################################################################
#
#
# QUESTION 3: What are John Biden's plans for the American economy ?
# ################################################################################
#
# [WITH RAG]
# Question: What are John Biden's plans for the American economy ?
# Answer (with RAG): Based on the provided context, it appears that President Biden has plans to strengthen the American economy through various initiatives. Some of these plans include:
#
# 1. Fortifying critical supply chains: In his first month in office, Biden signed an executive order directing agencies to focus attention on semiconductors, advanced battery technologies, and critical minerals.
# 2. Doubling financial commitment to climate crisis: In a speech to the UNGA, Biden announced that the US would double its financial commitment to helping developing nations tackle the climate crisis.
# 3. Improving relations with allies: Biden has staked his foreign policy agenda on improving relations with US allies and changing America's image abroad.
# 4. Closing inequality gaps: To convince the world of the value of democracy, G7 nations will need to ensure they close their own inequality gaps.
#
# It is worth noting that the context does not provide a comprehensive overview of Biden's economic plans, but rather highlights specific initiatives and themes that have been emphasized by his administration.
#
# Similarity scores between question and retrieved chunks:
# --------------------------------------------------------------------------------
# Chunk 1 (Article 249, Chunk 0)
# Title: Opinion: The US is starting to make a manufacturing comeback. Here's how to sustain it - CNN
# Similarity Score: 0.6277
# --------------------------------------------------------------------------------
# Chunk 2 (Article 2170, Chunk 15)
# Title: G7 summit: Joe Biden and Boris Johnson relish the role of global good guys. But bonhomie may be tested by hard reality - CNN
# Similarity Score: 0.5920
# --------------------------------------------------------------------------------
# Chunk 3 (Article 249, Chunk 9)
# Title: Opinion: The US is starting to make a manufacturing comeback. Here's how to sustain it - CNN
# Similarity Score: 0.5830
# --------------------------------------------------------------------------------
# Chunk 4 (Article 2889, Chunk 7)
# Title: UNGA: British PM Boris Johnson says the world needs to 'grow up' and deal with climate change - CNN
# Similarity Score: 0.5706
# --------------------------------------------------------------------------------
# Chunk 5 (Article 163, Chunk 19)
# Title: Fact check: A look at Biden's first year in false claims - CNNPolitics
# Similarity Score: 0.5422
# --------------------------------------------------------------------------------
# Chunk 6 (Article 2147, Chunk 23)
# Title: G7 leaders in Cornwall want to tackle inequality. Even people down the road aren't convinced - CNN
# Similarity Score: 0.5411
# --------------------------------------------------------------------------------
# Chunk 7 (Article 167, Chunk 3)
# Title: Why independents have cooled on Biden -- and what that means for Democrats - CNNPolitics
# Similarity Score: 0.5333
# --------------------------------------------------------------------------------
# Chunk 8 (Article 728, Chunk 8)
# Title: One of the last Guantanamo detainees is a litmus test for Biden - CNNPolitics
# Similarity Score: 0.5269
# --------------------------------------------------------------------------------
# Chunk 9 (Article 982, Chunk 2)
# Title: Anna Hursey: Table tennis prodigy is helping US President Biden tackle the climate crisis - CNN
# Similarity Score: 0.5268
# --------------------------------------------------------------------------------
# Chunk 10 (Article 1033, Chunk 16)
# Title: How Biden fared in front of world leaders during his (virtual) global debut as US President - CNN
# Similarity Score: 0.5253
# --------------------------------------------------------------------------------
#
# Similarity Statistics:
# Average similarity score: 0.5569
# Maximum similarity score: 0.6277
# Minimum similarity score: 0.5253
#
# The following chunks were used:
#
# Chunk 1:
# Metadata: {'title': "Opinion: The US is starting to make a manufacturing comeback. Here's how to sustain it - CNN", 'article_id': 249, 'chunk_id': 0, 'source': 'CNN'}
# Content: Title: Opinion: The US is starting to make a manufacturing comeback. Here's how to sustain it - CNN
#
# Content: Brian Deese serves as the director of the White House National Economic Council, advising ...
#
# Chunk 2:
# Metadata: {'title': 'G7 summit: Joe Biden and Boris Johnson relish the role of global good guys. But bonhomie may be tested by hard reality - CNN', 'article_id': 2170, 'chunk_id': 15, 'source': 'CNN'}
# Content: .He'll be hoping a rebellion by some of his own MPs in London to challenge his government's cuts to the UK's foreign aid budget, from 0.7% of GDP to 0.5%, fails to materialize and puncture the generou...
#
# Chunk 3:
# Metadata: {'title': "Opinion: The US is starting to make a manufacturing comeback. Here's how to sustain it - CNN", 'article_id': 249, 'chunk_id': 9, 'source': 'CNN'}
# Content: . These concerns fueled President Biden's efforts to create a strategy to strengthen our manufacturing base. One month into office, he signed an executive order directing agencies to fortify our natio...
#
# Chunk 4:
# Metadata: {'title': "UNGA: British PM Boris Johnson says the world needs to 'grow up' and deal with climate change - CNN", 'article_id': 2889, 'chunk_id': 7, 'source': 'CNN'}
# Content: . In a speech to the UNGA on Tuesday, US President Joe Biden announced the US would double its financial commitment to helping developing nations tackle the climate crisis. In a meeting with Biden on ...
#
# Chunk 5:
# Metadata: {'title': "Fact check: A look at Biden's first year in false claims - CNNPolitics", 'article_id': 163, 'chunk_id': 19, 'source': 'CNN'}
# Content: . In an economic speech in November, he greatly exaggerated the extent of the decline in the unemployment rate during his tenure.To try to sell his economic policies, Biden sometimes made inaccurate s...
#
# Chunk 6:
# Metadata: {'title': "G7 leaders in Cornwall want to tackle inequality. Even people down the road aren't convinced - CNN", 'article_id': 2147, 'chunk_id': 23, 'source': 'CNN'}
# Content: . "Biden is driven by a strong sense that democracies need to prove the value of their system by acting more effectively together to counter China's influence around the world," Dworkin said.  To conv...
#
# Chunk 7:
# Metadata: {'title': 'Why independents have cooled on Biden -- and what that means for Democrats - CNNPolitics', 'article_id': 167, 'chunk_id': 3, 'source': 'CNN'}
# Content: . "Now these same unaffiliated voters are looking at the guy in the White House, Democrats in Congress, Democrats in the state legislatures, and I don't think they like what they see."After the freque...
#
# Chunk 8:
# Metadata: {'title': 'One of the last Guantanamo detainees is a litmus test for Biden - CNNPolitics', 'article_id': 728, 'chunk_id': 8, 'source': 'CNN'}
# Content: . Biden has staked his foreign policy agenda on improving relations with US allies and changing America's image abroad. He has sold his decisions to end combat missions in Afghanistan and Iraq as movi...
#
# Chunk 9:
# Metadata: {'title': 'Anna Hursey: Table tennis prodigy is helping US President Biden tackle the climate crisis - CNN', 'article_id': 982, 'chunk_id': 2, 'source': 'CNN'}
# Content: . "I was just at home, my parents just got a phone call and I was kind of like, what is this about? And they told me, but I was really excited," Hursey told CNN Sport. Just hours after he was sworn in...
#
# Chunk 10:
# Metadata: {'title': 'How Biden fared in front of world leaders during his (virtual) global debut as US President - CNN', 'article_id': 1033, 'chunk_id': 16, 'source': 'CNN'}
# Content: .On China, another area of difference between the US and Europe, Biden wants his allies at his side, telling them: "You know, we must prepare together for a long-term strategic competition with China....
#
# [WITHOUT RAG]
# Question: What are John Biden's plans for the American economy ?
# Answer (without RAG): Based on my analysis of CNN articles from 2020 to 2022, here are some key points about President Joe Biden's plans for the American economy:
#
# 1. **Infrastructure Investment**: President Biden has proposed a significant investment in infrastructure development, with a focus on upgrading America's roads, bridges, and public transportation systems. The American Jobs Plan, announced in March 2021, aims to create millions of jobs and stimulate economic growth through investments in clean energy, broadband, and other critical infrastructure projects.
# 2. **Taxation and Revenue**: Biden has proposed increasing taxes on corporations and high-income individuals to fund his economic agenda. The Corporate America Tax would increase the corporate tax rate from 21% to 28%, while the Individual Income Tax would see a top marginal rate of 39.6%. This plan aims to reduce income inequality and generate revenue for infrastructure investments.
# 3. **Minimum Wage Increase**: Biden has proposed raising the federal minimum wage to $15 per hour, which would benefit millions of low-wage workers. The Raise the Wage Act, introduced in Congress in 2021, aims to increase the minimum wage and improve working conditions for American workers.
# 4. **Trade Policy**: President Biden has taken a more protectionist approach to trade policy, with a focus on renegotiating trade agreements and addressing issues related to intellectual property theft and unfair trade practices. The administration has also imposed tariffs on Chinese goods in response to concerns over intellectual property theft and subsidies for state-owned enterprises.
# 5. **Climate Change and Clean Energy**: Biden has made climate change a key priority of his economic agenda, with plans to invest in clean energy technologies, reduce greenhouse gas emissions, and promote sustainable infrastructure development. The administration has set ambitious targets for reducing carbon emissions and has proposed significant investments in renewable energy projects.
# 6. **Worker Training and Education**: President Biden has emphasized the importance of worker training and education programs to help workers adapt to an increasingly automated economy. The administration has proposed investing in programs that provide workers with the skills they need to compete in the modern workforce.
#
# Some notable CNN articles from 2020-2022 that discuss these plans include:
#
# * "Biden's $1.9 trillion COVID-19 relief package includes infrastructure spending" (CNN, March 2021)
# * "Biden proposes corporate tax hike to fund infrastructure investments" (CNN, April 2021)
# * "Biden administration announces plan to raise federal minimum wage to $15 per hour" (CNN, May 2021)
# * "Biden's trade agenda: A new era of protectionism?" (CNN, June 2021)
# * "Biden administration proposes significant investments in clean energy and climate change mitigation" (CNN, July 2021)
#
# Please note that these plans are subject to change and may have evolved since the articles were published.
#
# ################################################################################
#
#
# QUESTION 4: What are the player transfers for football teams?
# ################################################################################
#
# [WITH RAG]
# Question: What are the player transfers for football teams?
# Answer (with RAG): The player transfers for football teams refer to the movement of players between clubs, which can be categorized into several types:
#
# 1. Free Transfers: Players are now allowed to move on free transfers when their deals with clubs expire.
# 2. International Transfers and Loans: A total of 133,225 international transfers and loans of professional players took place in 2019, involving 66,789 players and 8,264 clubs across 200 FIFA member associations.
# 3. Transfer Fees: The top 30 spending clubs all based in Europe spent a total of $48.5 billion on international transfers over the past decade, with the most spent on a player being Paris Saint-Germain's $262.45 million deal to bring Neymar from Barcelona in 2017.
#
# The context also provides information on the spending habits of football teams, including:
#
# * English clubs spent the most in the last decade at $12.4 billion, followed by Spain ($6.7 billion), Italy ($5.6 billion), Germany ($4.4 billion), and France ($4 billion).
# * Manchester City topped the spending charts with 130 incoming transfers, while Chelsea had 95.
# * Portuguese clubs Benfica and Sporting were the biggest benefactors from transfer fees, topping the list of clubs with a positive net balance from transfer fees.
#
# Overall, the player transfers for football teams involve a significant amount of movement between clubs, with international transfers and loans being a major aspect of the sport's global economy.
#
# Similarity scores between question and retrieved chunks:
# --------------------------------------------------------------------------------
# Chunk 1 (Article 2563, Chunk 3)
# Title: Transfer deadline day: Spending on international transfers nearly tripled in 10 years, FIFA says - CNN
# Similarity Score: 0.6444
# --------------------------------------------------------------------------------
# Chunk 2 (Article 2830, Chunk 11)
# Title: Super League: UEFA forced to drop disciplinary proceedings against remaining clubs - CNN
# Similarity Score: 0.6397
# --------------------------------------------------------------------------------
# Chunk 3 (Article 3080, Chunk 5)
# Title: European transfer window 2021 may be the best ever as clubs splurge on marquee signings - CNN
# Similarity Score: 0.6109
# --------------------------------------------------------------------------------
# Chunk 4 (Article 2563, Chunk 5)
# Title: Transfer deadline day: Spending on international transfers nearly tripled in 10 years, FIFA says - CNN
# Similarity Score: 0.6107
# --------------------------------------------------------------------------------
# Chunk 5 (Article 1858, Chunk 18)
# Title: Manchester City wins Premier League title in an 'insane' season for Pep Guardiola's team - CNN
# Similarity Score: 0.6071
# --------------------------------------------------------------------------------
# Chunk 6 (Article 2563, Chunk 2)
# Title: Transfer deadline day: Spending on international transfers nearly tripled in 10 years, FIFA says - CNN
# Similarity Score: 0.5853
# --------------------------------------------------------------------------------
# Chunk 7 (Article 3080, Chunk 4)
# Title: European transfer window 2021 may be the best ever as clubs splurge on marquee signings - CNN
# Similarity Score: 0.5847
# --------------------------------------------------------------------------------
# Chunk 8 (Article 2563, Chunk 1)
# Title: Transfer deadline day: Spending on international transfers nearly tripled in 10 years, FIFA says - CNN
# Similarity Score: 0.5688
# --------------------------------------------------------------------------------
# Chunk 9 (Article 2683, Chunk 7)
# Title: Premier League: $138m Jack Grealish transfer shows it's business as usual for top-flight elite - CNN
# Similarity Score: 0.5637
# --------------------------------------------------------------------------------
# Chunk 10 (Article 1913, Chunk 1)
# Title: Stiliyan Petrov's dream job was cut short by cancer; now he wants to help soccer stars plan for the future - CNN
# Similarity Score: 0.5626
# --------------------------------------------------------------------------------
#
# Similarity Statistics:
# Average similarity score: 0.5978
# Maximum similarity score: 0.6444
# Minimum similarity score: 0.5626
#
# The following chunks were used:
#
# Chunk 1:
# Metadata: {'title': 'Transfer deadline day: Spending on international transfers nearly tripled in 10 years, FIFA says - CNN', 'article_id': 2563, 'chunk_id': 3, 'source': 'CNN'}
# Content: .Read More"From 11,890 transfers conducted in 2011 to a peak of 18,079 in 2019, a total of 133,225 international transfers and loans of professional players took place," FIFA said."The transfers invol...
#
# Chunk 2:
# Metadata: {'title': 'Super League: UEFA forced to drop disciplinary proceedings against remaining clubs - CNN', 'article_id': 2830, 'chunk_id': 11, 'source': 'CNN'}
# Content: . Players are now allowed to move on free transfers when their deals with clubs expire....
#
# Chunk 3:
# Metadata: {'title': 'European transfer window 2021 may be the best ever as clubs splurge on marquee signings - CNN', 'article_id': 3080, 'chunk_id': 5, 'source': 'CNN'}
# Content: .37B) for the sixth summer transfer window in a row, according to Deloitte.READ: $138m Jack Grealish transfer shows it's business as usual for English Premier League's eliteRead MoreManchester United ...
#
# Chunk 4:
# Metadata: {'title': 'Transfer deadline day: Spending on international transfers nearly tripled in 10 years, FIFA says - CNN', 'article_id': 2563, 'chunk_id': 5, 'source': 'CNN'}
# Content: .1 million in 2011 to $640.5 million in 2019, almost a five-fold increase.Manchester City (130 incoming transfers) and Chelsea (95) topped the spending charts, while Portuguese clubs Benfica and Sport...
#
# Chunk 5:
# Metadata: {'title': "Manchester City wins Premier League title in an 'insane' season for Pep Guardiola's team - CNN", 'article_id': 1858, 'chunk_id': 18, 'source': 'CNN'}
# Content: . Kieran Maguire, a university lecturer on football finance and author of The Price of Football, told CNN Sport last year that the club spent £62 million ($77 million) on transfers in 2008, the summer...
#
# Chunk 6:
# Metadata: {'title': 'Transfer deadline day: Spending on international transfers nearly tripled in 10 years, FIFA says - CNN', 'article_id': 2563, 'chunk_id': 2, 'source': 'CNN'}
# Content: .63 billion was spent.In all, $48.5 billion was spent on international transfers over the past decade with the top 30 spending clubs all based in Europe.The most spent on a player was Paris Saint-Germ...
#
# Chunk 7:
# Metadata: {'title': 'European transfer window 2021 may be the best ever as clubs splurge on marquee signings - CNN', 'article_id': 3080, 'chunk_id': 4, 'source': 'CNN'}
# Content: .Manchester City's $138 million purchase of England star Jack Grealish, United's signings of Raphael Varane from Real Madrid and Jadon Sancho from Borussia Dortmund, and Chelsea's $135 million acquisi...
#
# Chunk 8:
# Metadata: {'title': 'Transfer deadline day: Spending on international transfers nearly tripled in 10 years, FIFA says - CNN', 'article_id': 2563, 'chunk_id': 1, 'source': 'CNN'}
# Content: Content:  (CNN)Spending on international transfer fees over the last decade increased from $2.66 billion in 2012 to a peak of $7.35 billion in 2019, while players' agents received $3.5 billion in comm...
#
# Chunk 9:
# Metadata: {'title': "Premier League: $138m Jack Grealish transfer shows it's business as usual for top-flight elite - CNN", 'article_id': 2683, 'chunk_id': 7, 'source': 'CNN'}
# Content: . "All of the other transfers that have gone above that value have been in Spain and France, so to a certain extent, given the Premier League is the world's richest league, it's surprising it's taken ...
#
# Chunk 10:
# Metadata: {'title': "Stiliyan Petrov's dream job was cut short by cancer; now he wants to help soccer stars plan for the future - CNN", 'article_id': 1913, 'chunk_id': 1, 'source': 'CNN'}
# Content: Content:  (CNN)You might gawk at Premier League footballers' million dollar salaries but playing careers are short and can sometimes be curtailed by injury, illness or poor form.And when a career come...
#
# [WITHOUT RAG]
# Question: What are the player transfers for football teams?
# Answer (without RAG): Based on my analysis of CNN articles from 2020 to 2022, here are some notable player transfers in the football world:
#
# 1. **Kylian Mbappé (Paris Saint-Germain to Arsenal)**: In January 2022, French forward Kylian Mbappé joined Arsenal from Paris Saint-Germain for a reported fee of £198 million, making him one of the most expensive signings in history.
# 2. **Paul Pogba (Manchester United to Manchester City)**: In August 2022, midfielder Paul Pogba rejoined his former club Manchester United on a free transfer after spending two years at Manchester City.
# 3. **Harry Kane (Tottenham Hotspur to Newcastle United)**: In July 2022, Tottenham Hotspur striker Harry Kane joined Newcastle United for an initial fee of £160 million, with the option to add another £20 million in the future.
# 4. **Neymar Jr. (Paris Saint-Germain to Barcelona)**: In August 2021, Brazilian forward Neymar Jr. returned to his former club Barcelona from Paris Saint-Germain after a reported transfer fee of €222 million.
# 5. **Romelu Lukaku (Inter Milan to Chelsea)**: In September 2021, Inter Milan striker Romelu Lukaku joined Chelsea for an initial fee of £85 million, with the option to add another £15 million in the future.
# 6. **Lautaro Martínez (Inter Milan to Tottenham Hotspur)**: In August 2022, Inter Milan striker Lautaro Martínez joined Tottenham Hotspur for a reported transfer fee of £67.5 million.
# 7. **Erling Haaland (Borussia Dortmund to Manchester City)**: In September 2022, Norwegian forward Erling Haaland joined Manchester City from Borussia Dortmund for a reported fee of £51 million plus add-ons.
# 8. **Jack Grealish (Aston Villa to Manchester City)**: In August 2021, Aston Villa midfielder Jack Grealish joined Manchester City for an initial fee of £100 million, with the option to add another £20 million in the future.
#
# These are just a few examples of notable player transfers during this period. There were many other significant deals made by football clubs around the world between 2020 and 2022.
#
# ################################################################################
#
#
# QUESTION 5: What are the main challenges currently facing U.S.Α domestic and foreign policy ?
# ################################################################################
#
# [WITH RAG]
# Question: What are the main challenges currently facing U.S.Α domestic and foreign policy ?
# Answer (with RAG): Based on the provided context, some of the main challenges currently facing U.S. domestic and foreign policy can be identified:
#
# Domestic Policy Challenges:
#
# 1. Climate Change: The United States is pushing for action on climate change, with President Biden announcing a plan to reduce emissions from power plants by 32% below 2005 levels by 2030.
# 2. Economic Impact of Climate Policies: The proposed climate policies may have significant economic implications, particularly for working families in the United States, who may struggle to afford increased utility rates.
#
# Foreign Policy Challenges:
#
# 1. European Diplomacy and NATO: Despite optimism about a more collaborative approach to shared priorities, European diplomats and officials are adamant that moves towards an independent defense policy and international "strategic autonomy" will not slow down.
# 2. China and the Indo-Pacific Region: The EU is concerned about challenges posed by China in the region, particularly with regards to its growing influence and potential military expansion.
# 3. Loss of Trust and Alliance: The withdrawal of troops from Afghanistan has led to a reevaluation of the EU's reliance on the United States or NATO for protection, with some member states seeking to develop their own defense policies.
# 4. Strategic Autonomy: The EU is exploring the possibility of developing its own military force, as outlined in the "Strategic Compass for Security and Defence" document.
#
# Overall, these challenges highlight the complexities and nuances of U.S. domestic and foreign policy, particularly in the context of climate change, economic policy, and international relations with key allies like Europe and China.
#
# Similarity scores between question and retrieved chunks:
# --------------------------------------------------------------------------------
# Chunk 1 (Article 496, Chunk 2)
# Title: COP21: Obama praises Paris climate change agreement - CNN
# Similarity Score: 0.4546
# --------------------------------------------------------------------------------
# Chunk 2 (Article 876, Chunk 15)
# Title: Trump has trashed America's most important alliance. The rift with Europe could take decades to repair - CNN
# Similarity Score: 0.4477
# --------------------------------------------------------------------------------
# Chunk 3 (Article 1319, Chunk 3)
# Title: UK calls Russia top threat, issues warning on China, promises to build more nuclear warheads - CNN
# Similarity Score: 0.4457
# --------------------------------------------------------------------------------
# Chunk 4 (Article 3568, Chunk 2)
# Title: The EU realizes it can't rely on America for protection. Now it has a blueprint for a new joint military force - CNN
# Similarity Score: 0.4447
# --------------------------------------------------------------------------------
# Chunk 5 (Article 510, Chunk 101)
# Title: Why so many who doubt climate change here? (Opinion) - CNN
# Similarity Score: 0.4410
# --------------------------------------------------------------------------------
# Chunk 6 (Article 876, Chunk 6)
# Title: Trump has trashed America's most important alliance. The rift with Europe could take decades to repair - CNN
# Similarity Score: 0.4380
# --------------------------------------------------------------------------------
# Chunk 7 (Article 1090, Chunk 18)
# Title: The EU is facing the most serious crises in its history. Many are wondering if anyone's  in charge - CNN
# Similarity Score: 0.4366
# --------------------------------------------------------------------------------
# Chunk 8 (Article 3568, Chunk 0)
# Title: The EU realizes it can't rely on America for protection. Now it has a blueprint for a new joint military force - CNN
# Similarity Score: 0.4341
# --------------------------------------------------------------------------------
# Chunk 9 (Article 3946, Chunk 10)
# Title: Russia's Vladimir Putin told Biden he would 'really like' to meet - CNN
# Similarity Score: 0.4261
# --------------------------------------------------------------------------------
# Chunk 10 (Article 514, Chunk 28)
# Title: Your questions about climate change answered - CNN
# Similarity Score: 0.4251
# --------------------------------------------------------------------------------
#
# Similarity Statistics:
# Average similarity score: 0.4394
# Maximum similarity score: 0.4546
# Minimum similarity score: 0.4251
#
# The following chunks were used:
#
# Chunk 1:
# Metadata: {'title': 'COP21: Obama praises Paris climate change agreement - CNN', 'article_id': 496, 'chunk_id': 2, 'source': 'CNN'}
# Content: .""The Paris agreement establishes the enduring framework the world needs to solve the climate crisis," the President said, speaking from the White House. "It creates the mechanism, the architecture, ...
#
# Chunk 2:
# Metadata: {'title': "Trump has trashed America's most important alliance. The rift with Europe could take decades to repair - CNN", 'article_id': 876, 'chunk_id': 15, 'source': 'CNN'}
# Content: .Despite optimism that Biden will restore a more collaborative approach to shared priorities, European diplomats and officials are adamant that moves towards an independent defense policy and internat...
#
# Chunk 3:
# Metadata: {'title': 'UK calls Russia top threat, issues warning on China, promises to build more nuclear warheads - CNN', 'article_id': 1319, 'chunk_id': 3, 'source': 'CNN'}
# Content: .The document reaffirms the UK's defense and economic partnerships with the US as its most important in the world, and it makes a strong commitment to the NATO alliance but pledges to expand Britain's...
#
# Chunk 4:
# Metadata: {'title': "The EU realizes it can't rely on America for protection. Now it has a blueprint for a new joint military force - CNN", 'article_id': 3568, 'chunk_id': 2, 'source': 'CNN'}
# Content: . Recent geopolitical crises, most notably the messy withdrawal of troops from Afghanistan, has cemented thinking that the EU cannot rely entirely on the United States or NATO for its protection.Coinc...
#
# Chunk 5:
# Metadata: {'title': 'Why so many who doubt climate change here? (Opinion) - CNN', 'article_id': 510, 'chunk_id': 101, 'source': 'CNN'}
# Content: .We already have a mandate to move forward. The United States, long a laggard in international climate negotiations, is pushing for action. President Obama, for example, announced on Monday a plan to ...
#
# Chunk 6:
# Metadata: {'title': "Trump has trashed America's most important alliance. The rift with Europe could take decades to repair - CNN", 'article_id': 876, 'chunk_id': 6, 'source': 'CNN'}
# Content: . This week's snub of Pompeo brings an ignominious end to four years of exacerbation with a White House that went out of its way to burn bridges with allies who were caught off guard by the election o...
#
# Chunk 7:
# Metadata: {'title': "The EU is facing the most serious crises in its history. Many are wondering if anyone's  in charge - CNN", 'article_id': 1090, 'chunk_id': 18, 'source': 'CNN'}
# Content: .   The impact this has on Europe's foreign policy is significant. "You have 27 member states acting in their national interest, you have diplomats briefing journalists on every statement you make, an...
#
# Chunk 8:
# Metadata: {'title': "The EU realizes it can't rely on America for protection. Now it has a blueprint for a new joint military force - CNN", 'article_id': 3568, 'chunk_id': 0, 'source': 'CNN'}
# Content: Title: The EU realizes it can't rely on America for protection. Now it has a blueprint for a new joint military force - CNN...
#
# Chunk 9:
# Metadata: {'title': "Russia's Vladimir Putin told Biden he would 'really like' to meet - CNN", 'article_id': 3946, 'chunk_id': 10, 'source': 'CNN'}
# Content: understands from the leader of the United States, exactly what he risks if he pursues aggression with Ukraine...
#
# Chunk 10:
# Metadata: {'title': 'Your questions about climate change answered - CNN', 'article_id': 514, 'chunk_id': 28, 'source': 'CNN'}
# Content: . But here is the bottom line. Every proposal they put forward are going to be proposals that will make it harder to do business in America, that will make it harder to create jobs in America. ... May...
#
# [WITHOUT RAG]
# Question: What are the main challenges currently facing U.S.Α domestic and foreign policy ?
# Answer (without RAG): Based on my analysis of CNN articles from 2020 to 2022, I have identified some of the main challenges currently facing U.S. domestic and foreign policy:
#
# **Domestic Policy Challenges:**
#
# 1. **Partisan Gridlock**: The COVID-19 pandemic has exacerbated existing partisan divisions in Congress, making it difficult for lawmakers to pass legislation on key issues such as economic stimulus, healthcare reform, and infrastructure development.
# 2. **Racial Tensions and Social Unrest**: Protests against police brutality and systemic racism have highlighted deep-seated social and economic inequalities in the United States, leading to calls for greater accountability and reform.
# 3. **Economic Inequality**: The widening wealth gap between the rich and the poor has become a pressing concern, with many Americans struggling to make ends meet due to rising costs of living, stagnant wages, and limited access to affordable healthcare.
# 4. **Climate Change and Environmental Policy**: As the effects of climate change become more apparent, the U.S. government is facing increasing pressure to take action on issues such as carbon emissions reduction, renewable energy development, and environmental protection.
#
# **Foreign Policy Challenges:**
#
# 1. **China's Rise and Competition**: The United States is grappling with the implications of China's growing economic and military power, including concerns about intellectual property theft, trade imbalances, and regional security threats.
# 2. **Iran Nuclear Deal and Middle East Tensions**: The U.S. withdrawal from the Iran nuclear deal in 2018 has led to increased tensions between the United States and Iran, with ongoing conflicts in Yemen and Syria contributing to regional instability.
# 3. **North Korea's Nuclear Program**: The North Korean nuclear program remains a major concern for the United States, with ongoing diplomatic efforts aimed at denuclearization and peace on the Korean Peninsula.
# 4. **Russia's Aggressive Behavior**: Russia's actions in Ukraine, including the annexation of Crimea and support for separatist groups, have raised concerns about Russian aggression and the need for increased military preparedness and diplomacy.
#
# **Global Challenges:**
#
# 1. **Pandemic Response and Global Health Security**: The COVID-19 pandemic has highlighted the need for global cooperation on health security, with the United States playing a key role in international efforts to develop vaccines, distribute medical supplies, and support vulnerable countries.
# 2. **Climate Change and Global Governance**: As climate change becomes an increasingly pressing global issue, the United States is facing pressure to take a more active role in international efforts to address this challenge, including through the Paris Agreement and other global frameworks.
# 3. **Cybersecurity Threats and International Cooperation**: The rise of cyber threats from countries such as China and Russia has led to increased calls for greater international cooperation on cybersecurity issues, with the United States playing a key role in developing new norms and standards.
#
# These are just some of the main challenges facing U.S. domestic and foreign policy, based on my analysis of CNN articles from 2020 to 2022.
#
# ################################################################################
#
# Summary evaluation results:
#                                             question  num_source_docs  \
# 0  How did the COVID-19 pandemic affect the globa...               10
# 1         News about the summer Olymbic games 2020 ?               10
# 2  What are John Biden's plans for the American e...               10
# 3  What are the player transfers for football teams?               10
# 4  What are the main challenges currently facing ...               10
#
#    avg_similarity  max_similarity  min_similarity
# 0        0.599126        0.640436        0.567098
# 1        0.572482        0.629303        0.557142
# 2        0.556898        0.627699        0.525329
# 3        0.597792        0.644366        0.562622
# 4        0.439361        0.454634        0.425051
# =======================================================================================================
# #################################### END RAG SYSTEM EVALUATION ########################################

# %% [markdown]
#  avg_similarity  max_similarity  min_similarity
# 0        0.599126        0.640436        0.567098
# 1        0.570741        0.629303        0.553037
# 2        0.550139        0.591970        0.525329
# 3        0.597792        0.644366        0.562622
# 4        0.438194        0.454634        0.422457
